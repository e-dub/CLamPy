# %%
import LamPy as clt

# %%
Laminate1 = clt.laminate()

# %%
Laminate1.deg2rad()
Laminate1.calcPlyPositions()
Laminate1.calcPoisson21()
Laminate1.calcABD()
Laminate1.cleanABD()
Laminate1.calcInverseABD()
Laminate1.calcLaminateParameters()
Laminate1.calcStrain()
Laminate1.calcStress()
Laminate1.calcMisesStress()
Laminate1.calcFailureTsaiWu()
Laminate1.calcMass()

# %%
Laminate1.plotStackLayup()

# %%
Laminate1.plotPlyStrainStress()

# %%
Laminate1.plotPlyStrainStressPly()

# %%
Laminate1.writeTablePly(LaminateCooSys=True, PlyCooSys=True, PlyTop=True, PlyBottom=True)
# Out:
#  Laminate top reference system characteristics
#  ply  fiber orientation  strain x  stress x  strain y  stress y  strain xy  stress xy  Tsai-Wu reserve
#    1              -45.0    0.0030   32.1646   -0.0009    3.0556     0.0020     0.1579           2.0558
#    2              -30.0    0.0019   75.6344   -0.0006   16.9108     0.0016   -28.2137           3.6880
#    3                0.0   -0.0003  -37.0801   -0.0002   -2.2035     0.0008     3.1812          20.3358
#  Laminate bottom reference system characteristics
#  ply  fiber orientation  strain x  stress x  strain y  stress y  strain xy  stress xy  Tsai-Wu reserve
#    1              -45.0    0.0019    6.1383   -0.0006  -13.1037     0.0016    15.4284           2.0558
#    2              -30.0    0.0008    6.1685   -0.0004   -2.8755     0.0012     4.8665           3.6880
#    3                0.0    0.0008  116.9742   -0.0004   -1.7837     0.0012     4.5797          20.3358
#  Ply top reference system characteristics
#  ply  fiber orientation  strain 1  stress 1  strain 2  stress 2  strain 12  stress 12  Tsai-Wu reserve
#    1              -45.0    0.0001   17.4522    0.0021   17.7681     0.0039    14.5545           2.0558
#    2              -30.0    0.0006   85.3873    0.0007    7.1579     0.0030    11.3212           3.6880
#    3                0.0   -0.0003  -37.0801   -0.0002   -2.2035     0.0008     3.1812          20.3358
#  Ply bottom reference system characteristics
#  ply  fiber orientation  strain 1  stress 1  strain 2  stress 2  strain 12  stress 12  Tsai-Wu reserve
#    1              -45.0   -0.0002   17.4522    0.0014   17.7681     0.0026    14.5545           2.0558
#    2              -30.0   -0.0000   85.3873    0.0004    7.1579     0.0017    11.3212           3.6880
#    3                0.0    0.0008  -37.0801   -0.0004   -2.2035     0.0012     3.1812          20.3358
